# %%
import pandas as pd
df = pd.read_csv('diamonds.csv')
df= df.sample(n=5000)
df.shape
# Out:
# (5000, 10)

# %%
df.drop('x', axis=1, inplace=True)
df.drop('y', axis=1, inplace=True)
df.drop('z', axis=1, inplace=True)
df.head()
# Out:
#        carat        cut color clarity  depth  table  price
# 1854    0.65      Ideal     H      IF   61.5   55.0   3065
# 51924   0.70       Fair     E     VS2   65.7   55.0   2437
# 34512   0.33  Very Good     H      IF   60.3   59.0    868
# 44885   0.50      Ideal     E     VS2   62.2   56.0   1629
# 30798   0.34      Ideal     D     VS1   61.3   56.0    742

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# dtype: int64

# %%
df.describe()
# Out:
#              carat        depth        table         price
# count  5000.000000  5000.000000  5000.000000   5000.000000
# mean      0.797486    61.728120    57.514960   3957.752400
# std       0.476488     1.416995     2.300566   4015.674444
# min       0.200000    53.200000    43.000000    337.000000
# 25%       0.390000    61.000000    56.000000    928.750000
# 50%       0.710000    61.800000    57.000000   2401.500000
# 75%       1.040000    62.500000    59.000000   5408.000000
# max       3.000000    78.200000    95.000000  18818.000000

# %%
# #checking classified features's unique values
# print(df['Seller_Type'].unique())
# print(df['Transmission'].unique())
# print(df['Owner'].unique())
# print(df['Fuel_Type'].unique())

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price'], dtype='object')

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price
# 1854    0.65      Ideal     H      IF   61.5   55.0   3065
# 51924   0.70       Fair     E     VS2   65.7   55.0   2437
# 34512   0.33  Very Good     H      IF   60.3   59.0    868
# 44885   0.50      Ideal     E     VS2   62.2   56.0   1629
# 30798   0.34      Ideal     D     VS1   61.3   56.0    742
# ...      ...        ...   ...     ...    ...    ...    ...
# 16181   1.00    Premium     F     VS2   62.4   60.0   6468
# 30989   0.37    Premium     H    VVS2   61.3   58.0    746
# 37129   0.39      Ideal     F     VS2   62.3   55.0    971
# 26624   2.14    Premium     H     VS2   61.7   58.0  16390
# 44058   0.67      Ideal     H     SI1   62.1   54.0   1550
#
# [5000 rows x 7 columns]

# %%
#checking classified features's unique values
print(df['color'].unique())
print(df['clarity'].unique())
print(df['cut'].unique())
# Out:
# ['H' 'E' 'D' 'F' 'G' 'I' 'J']
# ['IF' 'VS2' 'VS1' 'SI2' 'SI1' 'VVS1' 'VVS2' 'I1']
# ['Ideal' 'Fair' 'Very Good' 'Premium' 'Good']

# %%
final_dataset = pd.get_dummies(df,drop_first=True)
final_dataset
# Out:
#        carat  depth  table  price  cut_Good  cut_Ideal  cut_Premium  \
# 1854    0.65   61.5   55.0   3065         0          1            0
# 51924   0.70   65.7   55.0   2437         0          0            0
# 34512   0.33   60.3   59.0    868         0          0            0
# 44885   0.50   62.2   56.0   1629         0          1            0
# 30798   0.34   61.3   56.0    742         0          1            0
# ...      ...    ...    ...    ...       ...        ...          ...
# 16181   1.00   62.4   60.0   6468         0          0            1
# 30989   0.37   61.3   58.0    746         0          0            1
# 37129   0.39   62.3   55.0    971         0          1            0
# 26624   2.14   61.7   58.0  16390         0          0            1
# 44058   0.67   62.1   54.0   1550         0          1            0
#
#        cut_Very Good  color_E  color_F  ...  color_H  color_I  color_J  \
# 1854               0        0        0  ...        1        0        0
# ...

# %%
final_dataset.corr()
# Out:
#                   carat     depth     table     price  cut_Good  cut_Ideal  \
# carat          1.000000  0.033341  0.200362  0.923774  0.058313  -0.186651
# depth          0.033341  1.000000 -0.297458 -0.016322  0.122256  -0.024278
# table          0.200362 -0.297458  1.000000  0.139637  0.184751  -0.547970
# price          0.923774 -0.016322  0.139637  1.000000  0.010808  -0.112064
# cut_Good       0.058313  0.122256  0.184751  0.010808  1.000000  -0.248951
# cut_Ideal     -0.186651 -0.024278 -0.547970 -0.112064 -0.248951   1.000000
# cut_Premium    0.112788 -0.180003  0.320780  0.091243 -0.180607  -0.495450
# cut_Very Good  0.025274  0.028520  0.128390  0.022796 -0.157936  -0.433257
# color_E       -0.122177 -0.042508  0.014510 -0.091220 -0.009099  -0.011500
# color_F       -0.063107  0.001786 -0.004917 -0.026275  0.006850   0.005631
# color_G       -0.048634 -0.013980 -0.060822  0.000091 -0.046142   0.053513
# ...

# %%
final_dataset.head()
# Out:
#        carat  depth  table  price  cut_Good  cut_Ideal  cut_Premium  \
# 1854    0.65   61.5   55.0   3065         0          1            0
# 51924   0.70   65.7   55.0   2437         0          0            0
# 34512   0.33   60.3   59.0    868         0          0            0
# 44885   0.50   62.2   56.0   1629         0          1            0
# 30798   0.34   61.3   56.0    742         0          1            0
#
#        cut_Very Good  color_E  color_F  ...  color_H  color_I  color_J  \
# 1854               0        0        0  ...        1        0        0
# 51924              0        1        0  ...        0        0        0
# 34512              1        0        0  ...        1        0        0
# 44885              0        1        0  ...        0        0        0
# 30798              0        0        0  ...        0        0        0
#
#        clarity_IF  clarity_SI1  clarity_SI2  clarity_VS1  clarity_VS2  \
# ...

# %%
#x=pd.merge(final_dataset.iloc[:,:3] ,final_dataset.iloc[:,4:])
x=final_dataset.drop("price", axis='columns')
y=final_dataset.iloc[:,3]
x.head()
# Out:
#        carat  depth  table  cut_Good  cut_Ideal  cut_Premium  cut_Very Good  \
# 1854    0.65   61.5   55.0         0          1            0              0
# 51924   0.70   65.7   55.0         0          0            0              0
# 34512   0.33   60.3   59.0         0          0            0              1
# 44885   0.50   62.2   56.0         0          1            0              0
# 30798   0.34   61.3   56.0         0          1            0              0
#
#        color_E  color_F  color_G  color_H  color_I  color_J  clarity_IF  \
# 1854         0        0        0        1        0        0           1
# 51924        1        0        0        0        0        0           0
# 34512        0        0        0        1        0        0           1
# 44885        1        0        0        0        0        0           0
# 30798        0        0        0        0        0        0           0
#
#        clarity_SI1  clarity_SI2  clarity_VS1  clarity_VS2  clarity_VVS1  \
# ...

# %%
y.head()
# Out:
# 1854     3065
# 51924    2437
# 34512     868
# 44885    1629
# 30798     742
# Name: price, dtype: int64

# %%
#Feature importance
import sklearn
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(x,y)
print(model.feature_importances_)
# Out:
# [0.87924792 0.01047522 0.00525707 0.00230298 0.0037043  0.0014354
#  0.00164021 0.00204738 0.0021854  0.00500763 0.00702732 0.00843981
#  0.00963144 0.00382966 0.00851929 0.01667365 0.00683746 0.00677358
#  0.00709515 0.01186912]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_,index = x.columns)
feat_importances.nlargest(5).plot(kind = 'barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
x_test.head()
# Out:
#        carat  depth  table  cut_Good  cut_Ideal  cut_Premium  cut_Very Good  \
# 20527   1.52   61.3   57.0         0          1            0              0
# 50593   0.77   62.2   58.0         0          0            1              0
# 47662   0.23   61.8   58.0         0          0            0              1
# 1728    0.32   61.8   57.0         0          1            0              0
# 41853   0.39   63.6   60.2         1          0            0              0
#
#        color_E  color_F  color_G  color_H  color_I  color_J  clarity_IF  \
# 20527        0        0        1        0        0        0           0
# 50593        0        1        0        0        0        0           0
# 47662        1        0        0        0        0        0           0
# 1728         0        0        1        0        0        0           0
# 41853        0        0        0        0        0        0           0
#
#        clarity_SI1  clarity_SI2  clarity_VS1  clarity_VS2  clarity_VVS1  \
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random = RandomForestRegressor()

# %%
#Randomized search CV
import numpy as np
#Number of trees in random forest
n_estimators = [int(X) for X in np.linspace(start=100,stop=1200,num=12)]
#Number of features to consider at every split
max_features = ['sqrt']
#Maximum number of levels in tree
max_depth = [int(X) for X in np.linspace(5,30,num=6)]
#max_depth.append(None)
#Minimum number of samples required to split a node
min_samples_split = [2,5,10,15,100]
#Minimum number of samples required at each leaf node
min_samples_leaf = [1,2,5,10]

# %%
from sklearn.model_selection import RandomizedSearchCV
#Create the random grid
random_grid = {'n_estimators' : n_estimators,
              'max_features':max_features,
              'max_depth':max_depth,
              'min_samples_split':min_samples_split,
              'min_samples_leaf':min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
#Use randomized grid search for best hyperparameters
#First create the base model to tune
rf = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, scoring = 'neg_mean_squared_error',n_iter = 10, cv = 5, verbose = 2, random_state = 42, n_jobs = 1)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1100; total time=   2.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1100; total time=   2.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1100; total time=   2.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1100; total time=   2.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1100; total time=   2.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   2.1s
# ...

# %%
prediction = rf_random.predict(x_test)
prediction
# Out:
# array([ 8953.32947325,  2630.73501586,   894.2643206 ,   840.31310992,
#         2042.4522809 ,  2962.18999345,  1000.87128555,  6022.55310066,
#        10205.74766581, 13505.32088587,  2040.24803945,   853.16751451,
#         4549.57794885,  2994.02142969,  6774.68653478,  1038.53421771,
#         2153.08828317,  1241.79432542,  6785.80103609,  1660.79992495,
#        11553.19043983, 11343.43733144,  8346.04266109,  1199.34085187,
#        10091.59563117,  4400.34855029,  1274.21643367,  7977.17208135,
#         1266.90423217,  6320.78225188, 10375.62990694,  1847.55193367,
#         1741.72784275,  5005.38708214, 12446.60154663,   856.85980111,
#         1202.47334183, 10471.5514607 ,  1155.06761021,  2109.49500671,
#         7708.3499139 ,  3780.25861584,  6716.61615138,  1631.22000784,
#         5298.89110267,   883.26690276,  1495.37758593,  1503.8266911 ,
#         2217.43788816,  4417.67650043,  4003.27540143,  9517.86884902,
# ...

# %%
import seaborn as sns
sns.distplot(y_test-prediction)
# Out:
# /var/folders/c7/s95zy2755fs4kbnrl2y6x1280000gn/T/ipykernel_6172/382743513.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-prediction)
# <AxesSubplot: xlabel='price', ylabel='Density'>

# %%
plt.scatter(y_test,prediction)

# %%
import pickle
#open a file, where you want to store the data
file = open('diamond.pkl','wb')

#dump information to that file
pickle.dump(rf_random,file)

# %%
with open('diamond.pkl', 'rb') as f:
    data = pickle.load(f)

print(type(data))
# Out:
# <class 'sklearn.model_selection._search.RandomizedSearchCV'>

# %%
import sys

print(sys.version)
